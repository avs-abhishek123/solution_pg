# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/content/EDA_Gold_Silver_prices.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       Month  SilverPrice  GoldPrice
# 0    Mar-97       186.48   12619.24
# 1    Apr-97       170.65   12338.59
# 2    May-97       170.44   12314.94
# 3    Jun-97       169.96   12202.78
# 4    Jul-97       155.80   11582.07
# ..      ...          ...        ...
# 236  Nov-16      1175.45   83622.54
# 237  Dec-16      1115.72   78583.48
# 238  Jan-17      1151.15   81191.05
# 239  Feb-17      1203.35   82818.17
# 240  Mar-17      1162.15   81169.45
#
# [241 rows x 3 columns]>

# %%
df.corr()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.954256
# GoldPrice       0.954256   1.000000

# %%
df.set_index("Month")
# Out:
#         SilverPrice  GoldPrice
# Month
# Mar-97       186.48   12619.24
# Apr-97       170.65   12338.59
# May-97       170.44   12314.94
# Jun-97       169.96   12202.78
# Jul-97       155.80   11582.07
# ...             ...        ...
# Nov-16      1175.45   83622.54
# Dec-16      1115.72   78583.48
# Jan-17      1151.15   81191.05
# Feb-17      1203.35   82818.17
# Mar-17      1162.15   81169.45
#
# [241 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        241 non-null    object
#  1   SilverPrice  241 non-null    float64
#  2   GoldPrice    241 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 5.8+ KB

# %%
df.iloc[1]
# Out:
# Month            Apr-97
# SilverPrice      170.65
# GoldPrice      12338.59
# Name: 1, dtype: object

# %%
df.iloc[130:142].corr()
# Out:
#              SilverPrice  GoldPrice
# SilverPrice     1.000000   0.009584
# GoldPrice       0.009584   1.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("/content/currencies.csv")

plt.matshow(df.corr())
plt.show()

# %%
corr = df.corr()

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/nas.csv")

# %%
df = df[["Mother.edu","Siblings"]]

# %%
df.head
# Out:
# <bound method NDFrame.head of         Mother.edu    Siblings
# 0       Illiterate   1 sibling
# 1       Illiterate  3 siblings
# 2       Illiterate  3 siblings
# 3        Secondary  3 siblings
# 4       Illiterate  2 siblings
# ...            ...         ...
# 8796     Secondary   1 sibling
# 8797     Secondary  2 siblings
# 8798     Secondary   1 sibling
# 8799  Sr secondary   1 sibling
# 8800     Secondary   1 sibling
#
# [8801 rows x 2 columns]>

# %%
a = df[df["Mother.edu"]=="Illiterate"]

# %%
a.head
# Out:
# <bound method NDFrame.head of       Mother.edu    Siblings
# 0     Illiterate   1 sibling
# 1     Illiterate  3 siblings
# 2     Illiterate  3 siblings
# 4     Illiterate  2 siblings
# 5     Illiterate  2 siblings
# ...          ...         ...
# 8778  Illiterate  2 siblings
# 8786  Illiterate  2 siblings
# 8789  Illiterate   1 sibling
# 8790  Illiterate   1 sibling
# 8792  Illiterate   1 sibling
#
# [2545 rows x 2 columns]>

# %%
 a['Siblings'].replace(a['Siblings'], '')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-b9b1496353d7> in <module>()
# ----> 1 a['Siblings'].replace(a['Siblings'], '')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4872             limit=limit,
#    4873             regex=regex,
# -> 4874             method=method,
#    4875         )
#    4876
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6550                     if self.ndim == 1:
#    6551                         raise ValueError(
# -> 6552                             "Series.replace cannot use dict-like to_replace "
#    6553                             "and non-None value"
#    6554                         )
#
# ...

# %%
a['Siblings'] = a['Siblings'].str.replace(' sibling', '')

# %%
a.head

# %%
a['Siblings'] = pd.to_numeric(a['Siblings'].astype(str).str[:1], errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
a.head
# Out:
# <bound method NDFrame.head of       Mother.edu  Siblings
# 0     Illiterate       1.0
# 1     Illiterate       3.0
# 2     Illiterate       3.0
# 4     Illiterate       2.0
# 5     Illiterate       2.0
# ...          ...       ...
# 8778  Illiterate       2.0
# 8786  Illiterate       2.0
# 8789  Illiterate       1.0
# 8790  Illiterate       1.0
# 8792  Illiterate       1.0
#
# [2545 rows x 2 columns]>

# %%
a.sort_values(by = 'Siblings')
# Out:
#       Mother.edu  Siblings
# 0     Illiterate       1.0
# 3913  Illiterate       1.0
# 3939  Illiterate       1.0
# 3940  Illiterate       1.0
# 4000  Illiterate       1.0
# ...          ...       ...
# 8133  Illiterate       NaN
# 8244  Illiterate       NaN
# 8551  Illiterate       NaN
# 8659  Illiterate       NaN
# 8737  Illiterate       NaN
#
# [2545 rows x 2 columns]

# %%
a['Siblings'].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2545 entries, 0 to 8792
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Mother.edu  2545 non-null   object
#  1   Siblings    2457 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 59.6+ KB

# %%
a.describe
# Out:
# <bound method NDFrame.describe of       Mother.edu  Siblings
# 0     Illiterate       1.0
# 1     Illiterate       3.0
# 2     Illiterate       3.0
# 4     Illiterate       2.0
# 5     Illiterate       2.0
# ...          ...       ...
# 8778  Illiterate       2.0
# 8786  Illiterate       2.0
# 8789  Illiterate       1.0
# 8790  Illiterate       1.0
# 8792  Illiterate       1.0
#
# [2545 rows x 2 columns]>

# %% [markdown]
# bivariate -2

# %%
df = pd.read_csv("/content/nas.csv")

# %%
df = df[["Father.edu","Age"]]

# %%
df.head
# Out:
# <bound method NDFrame.head of           Father.edu       Age
# 0         Illiterate  13 years
# 1                NaN  15 years
# 2     Degree & above  14 years
# 3          Secondary  13 years
# 4            Primary  14 years
# ...              ...       ...
# 8796       Secondary  13 years
# 8797             NaN  13 years
# 8798    Sr secondary  14 years
# 8799    Sr secondary  13 years
# 8800    Sr secondary  13 years
#
# [8801 rows x 2 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           Father.edu       Age
# 0         Illiterate  13 years
# 1                NaN  15 years
# 2     Degree & above  14 years
# 3          Secondary  13 years
# 4            Primary  14 years
# ...              ...       ...
# 8796       Secondary  13 years
# 8797             NaN  13 years
# 8798    Sr secondary  14 years
# 8799    Sr secondary  13 years
# 8800    Sr secondary  13 years
#
# [8801 rows x 2 columns]>

# %%
df[Father.edu"]
